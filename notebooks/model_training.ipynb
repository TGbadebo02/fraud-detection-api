# %% [markdown]
# # Fraud Detection Model Training
#
# Use this notebook to explore the transaction data, compare model options, and record training decisions. The executable baseline lives in `scripts/train_model.py` so the API and Docker build can reproduce the model.
